# %%
import numpy as np
import statistics as st
import pandas as pd

# %%
# Đọc từng file CSV với mã hóa 'ISO-8859-1' hoặc 'cp1252'
df_MBB = pd.read_csv('financial_data_MBB_filtered.csv',encoding='ISO-8859-1')

# Kiểm tra dữ liệu của từng DataFrame (nếu cần)
print("Data MBB:")
print(df_MBB.head())
# Out:
# Data MBB:
#   Quarter-Year  quarter  year    roe    roa  bookValuePerShare  \
# 0      Q4-2023        4  2023  0.245  0.025              18225
# 1      Q3-2023        3  2023  0.239  0.026              17293
# 2      Q2-2023        2  2023  0.243  0.025              16220
# 3      Q1-2023        1  2023  0.248  0.025              15974
# 4      Q4-2022        4  2022  0.258  0.026              15003
#
#    interestMargin  badDebtPercentage  provisionOnBadDebt  equityOnTotalAsset  \
# 0           0.048              0.016               1.170               0.102
# 1           0.055              0.019               1.220               0.112
# 2           0.055              0.014               1.561               0.107
# 3           0.056              0.018               1.383               0.111
# 4           0.057              0.011               2.380               0.109
#
#    ...  cancelDebt  bookValuePerShareChange  creditGrowth        Date  \
# ...

# %%
mean_roe = np.mean(df_MBB['roe'])
print(f"roe mean: {mean_roe}")
print(f"roe standard deviation: {st.stdev(df_MBB['roe'])}")
print(f"roe median: {st.median(df_MBB['roe'])}")

mean_roa = np.mean(df_MBB['roa'])
print(f"roa mean: {mean_roa}")
print(f"roa standard deviation: {st.stdev(df_MBB['roa'])}")
print(f"roa median: {st.median(df_MBB['roa'])}")

mean_bookValuePerShare = np.mean(df_MBB['bookValuePerShare'])
print(f"bookValuePerShare mean: {mean_bookValuePerShare}")
print(f"bookValuePerShare standard deviation: {st.stdev(df_MBB['bookValuePerShare'])}")
print(f"bookValuePerShare median: {st.median(df_MBB['bookValuePerShare'])}")

mean_interestMargin = np.mean(df_MBB['interestMargin'])
print(f"interestMargin mean: {mean_interestMargin}")
print(f"interestMargin standard deviation: {st.stdev(df_MBB['interestMargin'])}")
print(f"interestMargin median: {st.median(df_MBB['interestMargin'])}")

mean_badDebtPercentage = np.mean(df_MBB['badDebtPercentage'])
print(f"badDebtPercentage mean: {mean_badDebtPercentage}")
print(f"badDebtPercentage standard deviation: {st.stdev(df_MBB['badDebtPercentage'])}")
print(f"badDebtPercentage median: {st.median(df_MBB['badDebtPercentage'])}")

mean_provisionOnBadDebt = np.mean(df_MBB['provisionOnBadDebt'])
print(f"provisionOnBadDebt mean: {mean_provisionOnBadDebt}")
print(f"provisionOnBadDebt standard deviation: {st.stdev(df_MBB['provisionOnBadDebt'])}")
print(f"provisionOnBadDebt median: {st.median(df_MBB['provisionOnBadDebt'])}")

mean_equityOnTotalAsset = np.mean(df_MBB['equityOnTotalAsset'])
print(f"equityOnTotalAsset mean: {mean_equityOnTotalAsset}")
print(f"equityOnTotalAsset standard deviation: {st.stdev(df_MBB['equityOnTotalAsset'])}")
print(f"equityOnTotalAsset median: {st.median(df_MBB['equityOnTotalAsset'])}")
# Out:
# roe mean: 0.18297727272727274
# roe standard deviation: 0.0460391585785575
# roe median: 0.16949999999999998
# roa mean: 0.0175
# roa standard deviation: 0.005218482359799148
# roa median: 0.0155
# bookValuePerShare mean: 8923.84090909091
# bookValuePerShare standard deviation: 3937.1287905828485
# bookValuePerShare median: 8540.0
# interestMargin mean: 0.045000000000000005
# interestMargin standard deviation: 0.007077642492794755
# interestMargin median: 0.0455
# badDebtPercentage mean: 0.01625
# badDebtPercentage standard deviation: 0.006050658238264583
# badDebtPercentage median: 0.014
# provisionOnBadDebt mean: 1.2411818181818182
# provisionOnBadDebt standard deviation: 0.5272919968047038
# provisionOnBadDebt median: 1.046
# equityOnTotalAsset mean: 0.09890909090909092
# equityOnTotalAsset standard deviation: 0.009295705889901171
# equityOnTotalAsset median: 0.1015

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_MBB, x='roe', ax=ax1)  
ax1.set_xlabel('ROE')
ax1.set_title('Boxplot of ROE')

# Vẽ histogram ở dưới
ax2.hist(df_MBB['roe'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('ROE')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of ROE')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_MBB, x='roa', ax=ax1)  
ax1.set_xlabel('ROA')
ax1.set_title('Boxplot of ROA')

# Vẽ histogram ở dưới
ax2.hist(df_MBB['roa'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('ROA')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of ROA')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_MBB, x='bookValuePerShare', ax=ax1)  
ax1.set_xlabel('BookValuePerShare')
ax1.set_title('Boxplot of BookValuePerShare')

# Vẽ histogram ở dưới
ax2.hist(df_MBB['bookValuePerShare'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('BookValuePerShare')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of BookValuePerShare')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_MBB, x='interestMargin', ax=ax1)  
ax1.set_xlabel('interestMargin')
ax1.set_title('Boxplot of interestMargin')

# Vẽ histogram ở dưới
ax2.hist(df_MBB['interestMargin'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('interestMargin')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of interestMargin')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_MBB, x='badDebtPercentage', ax=ax1)  
ax1.set_xlabel('badDebtPercentage')
ax1.set_title('Boxplot of badDebtPercentage')

# Vẽ histogram ở dưới
ax2.hist(df_MBB['badDebtPercentage'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('badDebtPercentage')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of badDebtPercentage')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_MBB, x='provisionOnBadDebt', ax=ax1)  
ax1.set_xlabel('provisionOnBadDebt')
ax1.set_title('Boxplot of provisionOnBadDebt')

# Vẽ histogram ở dưới
ax2.hist(df_MBB['provisionOnBadDebt'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('provisionOnBadDebt')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of provisionOnBadDebt')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_MBB, x='equityOnTotalAsset', ax=ax1)  
ax1.set_xlabel('equityOnTotalAsset')
ax1.set_title('equityOnTotalAsset')

# Vẽ histogram ở dưới
ax2.hist(df_MBB['equityOnTotalAsset'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('equityOnTotalAsset')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of equityOnTotalAsset')

plt.tight_layout()
plt.show()
