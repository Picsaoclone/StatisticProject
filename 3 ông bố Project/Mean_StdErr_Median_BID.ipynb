# %%
import numpy as np
import statistics as st
import pandas as pd

# %%
# Đọc từng file CSV với mã hóa 'ISO-8859-1' hoặc 'cp1252'
df_BID = pd.read_csv('financial_data_BID_filtered.csv',encoding='ISO-8859-1')

# Kiểm tra dữ liệu của từng DataFrame (nếu cần)
print("Data BID:")
print(df_BID.head())
# Out:
# Data BID:
#   Quarter-Year  quarter  year    roe    roa  bookValuePerShare  \
# 0      Q4-2023        4  2023  0.198  0.010              21562
# 1      Q3-2023        3  2023  0.186  0.009              20891
# 2      Q2-2023        2  2023  0.202  0.010              20025
# 3      Q1-2023        1  2023  0.209  0.010              19270
# 4      Q4-2022        4  2022  0.198  0.009              18280
#
#    interestMargin  badDebtPercentage  provisionOnBadDebt  equityOnTotalAsset  \
# 0           0.026              0.013               1.818               0.053
# 1           0.027              0.016               1.584               0.056
# 2           0.028              0.016               1.515               0.054
# 3           0.029              0.015               1.713               0.052
# 4           0.029              0.012               2.168               0.049
#
#    ...  cancelDebt  bookValuePerShareChange  creditGrowth        Date  \
# ...

# %%
mean_roe = np.mean(df_BID['roe'])
print(f"roe mean: {mean_roe}")
print(f"roe standard deviation: {st.stdev(df_BID['roe'])}")
print(f"roe median: {st.median(df_BID['roe'])}")

mean_roa = np.mean(df_BID['roa'])
print(f"roa mean: {mean_roa}")
print(f"roa standard deviation: {st.stdev(df_BID['roa'])}")
print(f"roa median: {st.median(df_BID['roa'])}")

mean_bookValuePerShare = np.mean(df_BID['bookValuePerShare'])
print(f"bookValuePerShare mean: {mean_bookValuePerShare}")
print(f"bookValuePerShare standard deviation: {st.stdev(df_BID['bookValuePerShare'])}")
print(f"bookValuePerShare median: {st.median(df_BID['bookValuePerShare'])}")

mean_interestMargin = np.mean(df_BID['interestMargin'])
print(f"interestMargin mean: {mean_interestMargin}")
print(f"interestMargin standard deviation: {st.stdev(df_BID['interestMargin'])}")
print(f"interestMargin median: {st.median(df_BID['interestMargin'])}")

mean_badDebtPercentage = np.mean(df_BID['badDebtPercentage'])
print(f"badDebtPercentage mean: {mean_badDebtPercentage}")
print(f"badDebtPercentage standard deviation: {st.stdev(df_BID['badDebtPercentage'])}")
print(f"badDebtPercentage median: {st.median(df_BID['badDebtPercentage'])}")

mean_provisionOnBadDebt = np.mean(df_BID['provisionOnBadDebt'])
print(f"provisionOnBadDebt mean: {mean_provisionOnBadDebt}")
print(f"provisionOnBadDebt standard deviation: {st.stdev(df_BID['provisionOnBadDebt'])}")
print(f"provisionOnBadDebt median: {st.median(df_BID['provisionOnBadDebt'])}")

mean_equityOnTotalAsset = np.mean(df_BID['equityOnTotalAsset'])
print(f"equityOnTotalAsset mean: {mean_equityOnTotalAsset}")
print(f"equityOnTotalAsset standard deviation: {st.stdev(df_BID['equityOnTotalAsset'])}")
print(f"equityOnTotalAsset median: {st.median(df_BID['equityOnTotalAsset'])}")
# Out:
# roe mean: 0.14938636363636365
# roe standard deviation: 0.025269906644429494
# roe median: 0.1465
# roa mean: 0.007227272727272729
# roa standard deviation: 0.0013786349224763814
# roa median: 0.007
# bookValuePerShare mean: 12878.045454545454
# bookValuePerShare standard deviation: 3878.7031215165953
# bookValuePerShare median: 12074.0
# interestMargin mean: 0.02788636363636363
# interestMargin standard deviation: 0.001573263665876723
# interestMargin median: 0.028
# badDebtPercentage mean: 0.018272727272727274
# badDebtPercentage standard deviation: 0.004233661543324519
# badDebtPercentage median: 0.018
# provisionOnBadDebt mean: 1.0729772727272728
# provisionOnBadDebt standard deviation: 0.5424365567290887
# provisionOnBadDebt median: 0.8225
# equityOnTotalAsset mean: 0.0496590909090909
# equityOnTotalAsset standard deviation: 0.0054471805457979895
# equityOnTotalAsset median: 0.0505

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_BID, x='roe', ax=ax1)  
ax1.set_xlabel('ROE')
ax1.set_title('Boxplot of ROE')

# Vẽ histogram ở dưới
ax2.hist(df_BID['roe'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('ROE')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of ROE')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_BID, x='roa', ax=ax1)  
ax1.set_xlabel('ROA')
ax1.set_title('Boxplot of ROA')

# Vẽ histogram ở dưới
ax2.hist(df_BID['roa'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('ROA')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of ROA')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_BID, x='bookValuePerShare', ax=ax1)  
ax1.set_xlabel('BookValuePerShare')
ax1.set_title('Boxplot of BookValuePerShare')

# Vẽ histogram ở dưới
ax2.hist(df_BID['bookValuePerShare'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('BookValuePerShare')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of BookValuePerShare')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_BID, x='interestMargin', ax=ax1)  
ax1.set_xlabel('interestMargin')
ax1.set_title('Boxplot of interestMargin')

# Vẽ histogram ở dưới
ax2.hist(df_BID['interestMargin'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('interestMargin')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of interestMargin')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_BID, x='badDebtPercentage', ax=ax1)  
ax1.set_xlabel('badDebtPercentage')
ax1.set_title('Boxplot of badDebtPercentage')

# Vẽ histogram ở dưới
ax2.hist(df_BID['badDebtPercentage'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('badDebtPercentage')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of badDebtPercentage')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_BID, x='provisionOnBadDebt', ax=ax1)  
ax1.set_xlabel('provisionOnBadDebt')
ax1.set_title('Boxplot of provisionOnBadDebt')

# Vẽ histogram ở dưới
ax2.hist(df_BID['provisionOnBadDebt'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('provisionOnBadDebt')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of provisionOnBadDebt')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Vẽ boxplot ở trên
sns.boxplot(data=df_BID, x='equityOnTotalAsset', ax=ax1)  
ax1.set_xlabel('equityOnTotalAsset')
ax1.set_title('equityOnTotalAsset')

# Vẽ histogram ở dưới
ax2.hist(df_BID['equityOnTotalAsset'].dropna(), bins=20, edgecolor='black')  
ax2.set_xlabel('equityOnTotalAsset')
ax2.set_ylabel('Frequency')
ax2.set_title('Histogram of equityOnTotalAsset')

plt.tight_layout()
plt.show()
